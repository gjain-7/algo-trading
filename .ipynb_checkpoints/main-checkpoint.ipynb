# %%
# %pip install pyalgotrade
# %pip install pandas
# Out:
# Requirement already satisfied: pyalgotrade in c:\users\hp\anaconda3\lib\site-packages (0.20)
# Requirement already satisfied: requests in c:\users\hp\anaconda3\lib\site-packages (from pyalgotrade) (2.28.1)
# Requirement already satisfied: tweepy in c:\users\hp\anaconda3\lib\site-packages (from pyalgotrade) (4.12.1)
# Requirement already satisfied: numpy in c:\users\hp\anaconda3\lib\site-packages (from pyalgotrade) (1.21.5)
# Requirement already satisfied: matplotlib in c:\users\hp\anaconda3\lib\site-packages (from pyalgotrade) (3.5.2)
# Requirement already satisfied: six in c:\users\hp\anaconda3\lib\site-packages (from pyalgotrade) (1.16.0)
# Requirement already satisfied: python-dateutil in c:\users\hp\anaconda3\lib\site-packages (from pyalgotrade) (2.8.2)
# Requirement already satisfied: retrying in c:\users\hp\anaconda3\lib\site-packages (from pyalgotrade) (1.3.4)
# Requirement already satisfied: tornado in c:\users\hp\anaconda3\lib\site-packages (from pyalgotrade) (6.1)
# Requirement already satisfied: ws4py>=0.3.4 in c:\users\hp\anaconda3\lib\site-packages (from pyalgotrade) (0.5.1)
# Requirement already satisfied: scipy in c:\users\hp\anaconda3\lib\site-packages (from pyalgotrade) (1.9.1)
# Requirement already satisfied: pytz in c:\users\hp\anaconda3\lib\site-packages (from pyalgotrade) (2022.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->pyalgotrade) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->pyalgotrade) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->pyalgotrade) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->pyalgotrade) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->pyalgotrade) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->pyalgotrade) (1.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests->pyalgotrade) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests->pyalgotrade) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests->pyalgotrade) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests->pyalgotrade) (1.26.11)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in c:\users\hp\anaconda3\lib\site-packages (from tweepy->pyalgotrade) (3.2.2)
# Requirement already satisfied: requests-oauthlib<2,>=1.2.0 in c:\users\hp\anaconda3\lib\site-packages (from tweepy->pyalgotrade) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in c:\users\hp\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

from pyalgotrade import strategy, barfeed, bar, plotter
from pyalgotrade.bar import Frequency
from pyalgotrade.technical import ma, bollinger
from pyalgotrade.stratanalyzer import returns, sharpe

# %%
df = pd.read_csv("NIFTY50.csv")

cols = df.columns[1:] 
df[cols] = df[cols].apply(pd.to_numeric, errors='coerce', axis=1)
df['Date'] = pd.to_datetime(df['Date'])
df['Volume'] = np.iinfo(np.int32).max  

df.head()
# Out:
#         Date     Open     High      Low   Close      Volume
# 0 2012-12-03  5878.25  5899.15  5854.60  5870.9  2147483647
# 1 2012-12-04  5866.80  5894.95  5859.00  5889.2  2147483647
# 2 2012-12-05  5906.60  5917.80  5891.35  5900.5  2147483647
# 3 2012-12-06  5926.30  5942.55  5838.90  5930.9  2147483647
# 4 2012-12-07  5934.00  5949.85  5888.65  5907.4  2147483647

# %%
# Example BarFeed for dataframes with data for a single instrument.
class DataFrameBarFeed(barfeed.BaseBarFeed):
    def __init__(self, dataframe, instrument, frequency):
        super(DataFrameBarFeed, self).__init__(frequency)
        self.registerInstrument(instrument)
        self.__df = dataframe
        self.__instrument = instrument
        self.__next = 0

    def reset(self):
        super(DataFrameBarFeed, self).reset()
        self.__next = 0

    def peekDateTime(self):
        return self.getCurrentDateTime()

    def getCurrentDateTime(self):
        ret = None
        if not self.eof():
            rowkey = self.__df.index[self.__next]
            ret = df.iloc[rowkey]["Date"]
        return ret

    def barsHaveAdjClose(self):
        return False

    def getNextBars(self):
        ret = None
        if not self.eof():
            # Convert the dataframe row into a bar.BasicBar
            rowkey = self.__df.index[self.__next]
            row = self.__df.iloc[rowkey]
            bar_dict = {
                self.__instrument: bar.BasicBar(
                    row["Date"],
                    row["Open"],
                    row["High"],
                    row["Low"],
                    row["Close"],
                    row["Volume"],
                    None,  # row["Adj Close"],
                    self.getFrequency(),
                )
            }

            ret = bar.Bars(bar_dict)
            self.__next += 1
        return ret

    def eof(self):
        return self.__next >= len(self.__df.index)

    def start(self):
        pass

    def stop(self):
        pass

    def join(self):
        pass

# %%
class MyStrategy(strategy.BacktestingStrategy):
    def __init__(self, feed, instrument, capital):
        super(MyStrategy, self).__init__(feed, capital)
        self.__instrument = instrument
        self.__position = None
        self.__sma = ma.SMA(feed[instrument].getCloseDataSeries(), 15)

    @staticmethod
    def safe_round(value, digits):
        if value is not None:
            value = round(value, digits)
        return value

    def onEnterOk(self, position):
        execInfo = position.getEntryOrder().getExecutionInfo()
        self.info("BUY at \u20B9 %.2f" % (execInfo.getPrice()))

    def onEnterCanceled(self, position):
        self.__position = None

    def onExitOk(self, position):
        execInfo = position.getExitOrder().getExecutionInfo()
        self.info("SELL at \u20B9 %.2f" % (execInfo.getPrice()))
        self.__position = None

    def onExitCanceled(self, position):
        self.__position.exitMarket()

    def onBars(self, bars):
        if self.__sma[-1] is None:
            return

        bar = bars[self.__instrument]
        if self.__position is None:
            if bar.getPrice() > self.__sma[-1]:
                self.__position = self.enterLong(self.__instrument, 10, True)
        elif bar.getPrice() < self.__sma[-1] and not self.__position.exitActive():
            self.__position.exitMarket()


capital = 100000
feed = DataFrameBarFeed(df, "nifty", Frequency.DAY)
myStrategy = MyStrategy(feed, "nifty", capital)

returnsAnalyzer = returns.Returns()
myStrategy.attachAnalyzer(returnsAnalyzer)

plt = plotter.StrategyPlotter(myStrategy)

plt.getOrCreateSubplot("returns").addDataSeries("Simple returns", returnsAnalyzer.getReturns())


myStrategy.run()
myStrategy.info("Final portfolio value: $%.2f" % myStrategy.getResult())

# Plot the strategy.
plt.plot()
# Out:
# 2012-12-27 00:00:00 strategy [INFO] BUY at ₹ 5930.20
# 2012-12-28 00:00:00 strategy [INFO] SELL at ₹ 5887.15
# 2012-12-31 00:00:00 strategy [INFO] BUY at ₹ 5901.20
# 2013-02-01 00:00:00 strategy [INFO] SELL at ₹ 6040.95
# 2013-02-21 00:00:00 strategy [INFO] BUY at ₹ 5909.65
# 2013-02-22 00:00:00 strategy [INFO] SELL at ₹ 5837.95
# 2013-03-08 00:00:00 strategy [INFO] BUY at ₹ 5883.65
# 2013-03-20 00:00:00 strategy [INFO] SELL at ₹ 5740.55
# 2013-04-17 00:00:00 strategy [INFO] BUY at ₹ 5708.65
# 2013-05-24 00:00:00 strategy [INFO] SELL at ₹ 6010.70
# 2013-05-28 00:00:00 strategy [INFO] BUY at ₹ 6086.35
# 2013-06-03 00:00:00 strategy [INFO] SELL at ₹ 5997.35
# 2013-07-01 00:00:00 strategy [INFO] BUY at ₹ 5834.10
# 2013-07-26 00:00:00 strategy [INFO] SELL at ₹ 5937.95
# 2013-08-16 00:00:00 strategy [INFO] BUY at ₹ 5705.45
# 2013-08-19 00:00:00 strategy [INFO] SELL at ₹ 5497.55
# 2013-09-02 00:00:00 strategy [INFO] BUY at ₹ 5480.25
# 2013-09-04 00:00:00 strategy [INFO] SELL at ₹ 5358.65
# 2013-09-05 00:00:00 strategy [INFO] BUY at ₹ 5553.75
# 2013-09-30 00:00:00 strategy [INFO] SELL at ₹ 5801.05
# 2013-10-04 00:00:00 strategy [INFO] BUY at ₹ 5891.30
# 2013-11-08 00:00:00 strategy [INFO] SELL at ₹ 6170.15
# 2013-11-19 00:00:00 strategy [INFO] BUY at ₹ 6197.25
# 2013-11-21 00:00:00 strategy [INFO] SELL at ₹ 6096.50
# 2013-11-29 00:00:00 strategy [INFO] BUY at ₹ 6103.90
# 2013-12-16 00:00:00 strategy [INFO] SELL at ₹ 6168.35
# 2013-12-23 00:00:00 strategy [INFO] BUY at ₹ 6267.20
# 2014-01-03 00:00:00 strategy [INFO] SELL at ₹ 6194.55
# 2019-05-21 00:00:00 strategy [INFO] BUY at ₹ 11863.65
# 2019-06-17 00:00:00 strategy [INFO] SELL at ₹ 11844.00
# 2019-06-27 00:00:00 strategy [INFO] BUY at ₹ 11860.85
# 2019-07-01 00:00:00 strategy [INFO] SELL at ₹ 11839.90
# 2019-07-02 00:00:00 strategy [INFO] BUY at ₹ 11890.30
# 2019-07-09 00:00:00 strategy [INFO] SELL at ₹ 11531.60
# 2019-08-20 00:00:00 strategy [INFO] BUY at ₹ 11063.90
# 2019-08-22 00:00:00 strategy [INFO] SELL at ₹ 10905.30
# 2019-08-27 00:00:00 strategy [INFO] BUY at ₹ 11106.55
# 2019-08-30 00:00:00 strategy [INFO] SELL at ₹ 10987.80
# 2019-09-03 00:00:00 strategy [INFO] BUY at ₹ 10960.95
# 2019-09-04 00:00:00 strategy [INFO] SELL at ₹ 10790.40
# 2019-09-11 00:00:00 strategy [INFO] BUY at ₹ 11028.50
# 2019-09-18 00:00:00 strategy [INFO] SELL at ₹ 10872.80
# 2019-09-23 00:00:00 strategy [INFO] BUY at ₹ 11542.70
# 2019-10-07 00:00:00 strategy [INFO] SELL at ₹ 11196.20
# 2019-10-10 00:00:00 strategy [INFO] BUY at ₹ 11280.50
# 2019-10-11 00:00:00 strategy [INFO] SELL at ₹ 11257.70
# 2019-10-16 00:00:00 strategy [INFO] BUY at ₹ 11464.95
# 2019-11-25 00:00:00 strategy [INFO] SELL at ₹ 11922.45
# 2019-11-26 00:00:00 strategy [INFO] BUY at ₹ 12110.20
# 2019-12-09 00:00:00 strategy [INFO] SELL at ₹ 11939.10
# 2019-12-16 00:00:00 strategy [INFO] BUY at ₹ 12131.35
# 2020-01-07 00:00:00 strategy [INFO] SELL at ₹ 12079.10
# 2020-01-10 00:00:00 strategy [INFO] BUY at ₹ 12271.00
# 2020-01-21 00:00:00 strategy [INFO] SELL at ₹ 12195.30
# 2020-01-27 00:00:00 strategy [INFO] BUY at ₹ 12197.10
# 2020-01-28 00:00:00 strategy [INFO] SELL at ₹ 12148.10
# 2020-02-06 00:00:00 strategy [INFO] BUY at ₹ 12120.00
# 2020-02-11 00:00:00 strategy [INFO] SELL at ₹ 12108.40
# 2020-02-12 00:00:00 strategy [INFO] BUY at ₹ 12151.00
# 2020-02-19 00:00:00 strategy [INFO] SELL at ₹ 12090.60
# 2020-02-20 00:00:00 strategy [INFO] BUY at ₹ 12119.00
# 2020-02-25 00:00:00 strategy [INFO] SELL at ₹ 11877.50
# 2020-04-08 00:00:00 strategy [INFO] BUY at ₹ 8688.90
# 2020-05-06 00:00:00 strategy [INFO] SELL at ₹ 9226.80
# 2020-05-07 00:00:00 strategy [INFO] BUY at ₹ 9234.05
# 2020-05-08 00:00:00 strategy [INFO] SELL at ₹ 9376.95
# 2020-05-14 00:00:00 strategy [INFO] BUY at ₹ 9213.95
# 2020-05-15 00:00:00 strategy [INFO] SELL at ₹ 9182.40
# 2020-05-28 00:00:00 strategy [INFO] BUY at ₹ 9364.95
# 2020-06-16 00:00:00 strategy [INFO] SELL at ₹ 10014.80
# 2020-06-17 00:00:00 strategy [INFO] BUY at ₹ 9876.70
# 2022-10-17 00:00:00 strategy [INFO] BUY at ₹ 17144.80
# 2022-11-22 00:00:00 strategy [INFO] SELL at ₹ 18179.15
# 2022-11-23 00:00:00 strategy [INFO] BUY at ₹ 18325.20
# 2022-12-13 22:48:12,078 strategy [INFO] Final portfolio value: $203921.00

# %%
from pyalgotrade import strategy
from pyalgotrade.technical import bollinger
from pyalgotrade.stratanalyzer import sharpe

# Work in Progress
class BBands(strategy.BacktestingStrategy):
    def __init__(self, feed, instrument, bBandsPeriod, capital):
        super(BBands, self).__init__(feed, capital)
        self.__instrument = instrument
        self.__bbands = bollinger.BollingerBands(
            feed[instrument].getCloseDataSeries(), bBandsPeriod, 1.5
        )
        self.__position = None

    def getBollingerBands(self):
        return self.__bbands

    def onEnterCanceled(self, position):
        #restore position
        self.__position = None

    def onEnterOK(self, position):
        print(position)
        pass

    def onExitOk(self, position):
        self.__position = None

    def onExitCanceled(self, position):
        # If the exit was canceled, re-submit it.
        self.__position.exitMarket()

    def onBars(self, bars):
        lower = self.__bbands.getLowerBand()[-1]
        upper = self.__bbands.getUpperBand()[-1]
        if lower is None:
            return

        shares = self.getBroker().getShares(self.__instrument)
        bar = bars[self.__instrument]
        SL=0
        TL=0
        RR_ratio=3
        B=0
        

        if self.__position is None:
            if bar.getHigh() < lower:
                sharesToBuy = int(self.getBroker().getCash(False) / bar.getHigh())
                self.info("Placing Buy Stop order")
                self.__position=self.enterLongStop(self.__instrument, bar.getHigh(), sharesToBuy)
                SL=bar.getLow()
                TL=(bar.getHigh()-bar.getLow())*RR_ratio+bar.getPrice()

        elif (bar.getClose() <= SL or bar.getClose() >= TL) and not self.__position.exitActive():
            self.info("Placing Sell Market order")
            self.__position.exitMarket(goodTillCanceled=None)


# instrument = "nifty"
# bBandsPeriod = 40
# capital = 100000

# strat = BBands(feed, instrument, bBandsPeriod, capital)
# sharpeRatioAnalyzer = sharpe.SharpeRatio()
# strat.attachAnalyzer(sharpeRatioAnalyzer)

# plt = plotter.StrategyPlotter(strat, True, True, True)
# plt.getInstrumentSubplot(instrument).addDataSeries("upper", strat.getBollingerBands().getUpperBand())
# plt.getInstrumentSubplot(instrument).addDataSeries("lower", strat.getBollingerBands().getLowerBand())

# strat.run()
# #print("Sharpe ratio: %.2f" % sharpeRatioAnalyzer.getSharpeRatio(0.05))

# plt.plot()

capital = 100000
feed = DataFrameBarFeed(df, "nifty", Frequency.DAY)
myStrategy = BBands(feed, "nifty", 150, capital)

returnsAnalyzer = returns.Returns()
myStrategy.attachAnalyzer(returnsAnalyzer)

plt = plotter.StrategyPlotter(myStrategy)

plt.getOrCreateSubplot("returns").addDataSeries("Simple returns", returnsAnalyzer.getReturns())


myStrategy.run()
myStrategy.info("Final portfolio value: $%.2f" % myStrategy.getResult())

# Plot the strategy.
plt.plot()
# Out:
# 2013-08-07 00:00:00 strategy [INFO] Placing Buy Stop order
# 2013-08-08 00:00:00 strategy [INFO] Placing Sell Market order
# 2013-08-19 00:00:00 strategy [INFO] Placing Buy Stop order
# 2013-08-20 00:00:00 strategy [INFO] Placing Buy Stop order
# 2013-08-21 00:00:00 strategy [INFO] Placing Sell Market order
# 2013-08-22 00:00:00 strategy [INFO] Placing Buy Stop order
# 2013-08-23 00:00:00 strategy [INFO] Placing Sell Market order
# 2013-08-26 00:00:00 strategy [INFO] Placing Buy Stop order
# 2013-08-27 00:00:00 strategy [INFO] Placing Buy Stop order
# 2013-08-28 00:00:00 strategy [INFO] Placing Buy Stop order
# 2013-08-29 00:00:00 strategy [INFO] Placing Sell Market order
# 2013-08-30 00:00:00 strategy [INFO] Placing Buy Stop order
# 2013-09-02 00:00:00 strategy [INFO] Placing Sell Market order
# 2013-09-04 00:00:00 strategy [INFO] Placing Buy Stop order
# 2013-09-05 00:00:00 strategy [INFO] Placing Sell Market order
# 2015-06-09 00:00:00 strategy [INFO] Placing Buy Stop order
# 2015-06-10 00:00:00 strategy [INFO] Placing Sell Market order
# 2015-06-12 00:00:00 strategy [INFO] Placing Buy Stop order
# 2015-06-15 00:00:00 strategy [INFO] Placing Sell Market order
# 2015-06-16 00:00:00 strategy [INFO] Placing Buy Stop order
# 2015-06-17 00:00:00 strategy [INFO] Placing Sell Market order
# 2015-08-24 00:00:00 strategy [INFO] Placing Buy Stop order
# 2015-08-25 00:00:00 strategy [INFO] Placing Buy Stop order
# 2015-08-26 00:00:00 strategy [INFO] Placing Sell Market order
# 2015-08-27 00:00:00 strategy [INFO] Placing Buy Stop order
# 2015-08-28 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill nifty order [25] for 13 share/s
# 2015-08-31 00:00:00 strategy [INFO] Placing Buy Stop order
# 2015-09-01 00:00:00 strategy [INFO] Placing Buy Stop order
# 2015-09-02 00:00:00 strategy [INFO] Placing Buy Stop order
# 2015-09-03 00:00:00 strategy [INFO] Placing Buy Stop order
# 2015-09-04 00:00:00 strategy [INFO] Placing Buy Stop order
# 2015-09-07 00:00:00 strategy [INFO] Placing Buy Stop order
# 2015-09-08 00:00:00 strategy [INFO] Placing Sell Market order
# 2015-09-09 00:00:00 strategy [INFO] Placing Buy Stop order
# 2015-09-10 00:00:00 strategy [INFO] Placing Buy Stop order
# 2015-09-11 00:00:00 strategy [INFO] Placing Sell Market order
# 2015-09-14 00:00:00 strategy [INFO] Placing Buy Stop order
# 2015-09-15 00:00:00 strategy [INFO] Placing Sell Market order
# 2015-09-16 00:00:00 strategy [INFO] Placing Buy Stop order
# 2015-09-18 00:00:00 strategy [INFO] Placing Sell Market order
# 2015-09-23 00:00:00 strategy [INFO] Placing Buy Stop order
# 2015-09-24 00:00:00 strategy [INFO] Placing Sell Market order
# 2015-11-13 00:00:00 strategy [INFO] Placing Buy Stop order
# 2015-11-16 00:00:00 strategy [INFO] Placing Sell Market order
# 2015-12-09 00:00:00 strategy [INFO] Placing Buy Stop order
# 2015-12-10 00:00:00 strategy [INFO] Placing Buy Stop order
# 2015-12-11 00:00:00 strategy [INFO] Placing Sell Market order
# 2015-12-14 00:00:00 strategy [INFO] Placing Buy Stop order
# 2015-12-15 00:00:00 strategy [INFO] Placing Sell Market order
# 2016-01-08 00:00:00 strategy [INFO] Placing Buy Stop order
# 2016-01-11 00:00:00 strategy [INFO] Placing Buy Stop order
# 2016-01-12 00:00:00 strategy [INFO] Placing Buy Stop order
# 2016-01-13 00:00:00 strategy [INFO] Placing Sell Market order
# 2016-01-14 00:00:00 strategy [INFO] Placing Buy Stop order
# 2016-01-15 00:00:00 strategy [INFO] Placing Buy Stop order
# 2016-01-18 00:00:00 strategy [INFO] Placing Buy Stop order
# 2016-01-19 00:00:00 strategy [INFO] Placing Buy Stop order
# 2016-01-20 00:00:00 strategy [INFO] Placing Sell Market order
# 2016-01-21 00:00:00 strategy [INFO] Placing Buy Stop order
# 2016-01-22 00:00:00 strategy [INFO] Placing Sell Market order
# 2016-01-25 00:00:00 strategy [INFO] Placing Buy Stop order
# 2016-01-27 00:00:00 strategy [INFO] Placing Buy Stop order
# 2016-01-28 00:00:00 strategy [INFO] Placing Buy Stop order
# 2016-01-29 00:00:00 strategy [INFO] Placing Sell Market order
# 2016-02-03 00:00:00 strategy [INFO] Placing Buy Stop order
# 2016-02-04 00:00:00 strategy [INFO] Placing Sell Market order
# 2016-02-09 00:00:00 strategy [INFO] Placing Buy Stop order
# 2016-02-10 00:00:00 strategy [INFO] Placing Buy Stop order
# 2016-02-11 00:00:00 strategy [INFO] Placing Buy Stop order
# 2016-02-12 00:00:00 strategy [INFO] Placing Buy Stop order
# 2016-02-15 00:00:00 strategy [INFO] Placing Sell Market order
# 2016-02-16 00:00:00 strategy [INFO] Placing Buy Stop order
# 2016-02-17 00:00:00 strategy [INFO] Placing Buy Stop order
# 2016-02-18 00:00:00 strategy [INFO] Placing Sell Market order
# 2016-02-19 00:00:00 strategy [INFO] Placing Buy Stop order
# 2016-02-22 00:00:00 strategy [INFO] Placing Sell Market order
# 2016-02-23 00:00:00 strategy [INFO] Placing Buy Stop order
# 2016-02-24 00:00:00 strategy [INFO] Placing Buy Stop order
# 2016-02-25 00:00:00 strategy [INFO] Placing Buy Stop order
# 2016-02-26 00:00:00 strategy [INFO] Placing Sell Market order
# 2016-02-29 00:00:00 strategy [INFO] Placing Buy Stop order
# 2016-03-01 00:00:00 strategy [INFO] Placing Sell Market order
# 2016-12-26 00:00:00 strategy [INFO] Placing Buy Stop order
# 2016-12-27 00:00:00 strategy [INFO] Placing Sell Market order
# 2018-10-25 00:00:00 strategy [INFO] Placing Buy Stop order
# 2018-10-26 00:00:00 strategy [INFO] Placing Buy Stop order
# 2018-10-29 00:00:00 strategy [INFO] Placing Sell Market order
# 2020-03-09 00:00:00 strategy [INFO] Placing Buy Stop order
# 2020-03-11 00:00:00 strategy [INFO] Placing Buy Stop order
# 2020-03-12 00:00:00 strategy [INFO] Placing Buy Stop order
# 2020-03-13 00:00:00 strategy [INFO] Placing Sell Market order
# 2020-03-16 00:00:00 strategy [INFO] Placing Buy Stop order
# 2020-03-17 00:00:00 strategy [INFO] Placing Buy Stop order
# 2020-03-18 00:00:00 strategy [INFO] Placing Buy Stop order
# 2020-03-19 00:00:00 strategy [INFO] Placing Buy Stop order
# 2020-03-20 00:00:00 strategy [INFO] Placing Sell Market order
# 2020-03-23 00:00:00 strategy [INFO] Placing Buy Stop order
# 2020-03-24 00:00:00 strategy [INFO] Placing Buy Stop order
# 2020-03-25 00:00:00 strategy [INFO] Placing Sell Market order
# 2020-03-26 00:00:00 strategy [INFO] Placing Buy Stop order
# 2020-03-27 00:00:00 strategy [INFO] Placing Sell Market order
# 2020-03-30 00:00:00 strategy [INFO] Placing Buy Stop order
# 2020-03-31 00:00:00 strategy [INFO] Placing Sell Market order
# 2020-04-01 00:00:00 strategy [INFO] Placing Buy Stop order
# 2020-04-03 00:00:00 strategy [INFO] Placing Buy Stop order
# 2020-04-07 00:00:00 strategy [INFO] Placing Sell Market order
# 2020-04-08 00:00:00 strategy [INFO] Placing Buy Stop order
# 2020-04-09 00:00:00 strategy [INFO] Placing Buy Stop order
# 2020-04-13 00:00:00 strategy [INFO] Placing Buy Stop order
# 2020-04-15 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill nifty order [108] for 11 share/s
# 2020-04-15 00:00:00 strategy [INFO] Placing Buy Stop order
# 2020-04-16 00:00:00 strategy [INFO] Placing Buy Stop order
# 2020-04-17 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill nifty order [110] for 11 share/s
# 2020-04-17 00:00:00 strategy [INFO] Placing Buy Stop order
# 2020-04-20 00:00:00 strategy [INFO] Placing Sell Market order
# 2020-04-21 00:00:00 strategy [INFO] Placing Buy Stop order
# 2020-04-22 00:00:00 strategy [INFO] Placing Sell Market order
# 2020-04-23 00:00:00 strategy [INFO] Placing Buy Stop order
# 2020-04-24 00:00:00 strategy [INFO] Placing Buy Stop order
# 2020-04-27 00:00:00 strategy [INFO] Placing Sell Market order
# 2022-03-04 00:00:00 strategy [INFO] Placing Buy Stop order
# 2022-03-07 00:00:00 strategy [INFO] Placing Buy Stop order
# 2022-03-08 00:00:00 strategy [INFO] Placing Sell Market order
# 2022-03-09 00:00:00 strategy [INFO] Placing Buy Stop order
# 2022-03-10 00:00:00 strategy [INFO] Placing Sell Market order
# 2022-05-06 00:00:00 strategy [INFO] Placing Buy Stop order
# 2022-05-09 00:00:00 strategy [INFO] Placing Buy Stop order
# 2022-05-10 00:00:00 strategy [INFO] Placing Sell Market order
# 2022-05-11 00:00:00 strategy [INFO] Placing Buy Stop order
# 2022-05-12 00:00:00 strategy [INFO] Placing Buy Stop order
# 2022-05-13 00:00:00 strategy [INFO] Placing Sell Market order
# 2022-05-16 00:00:00 strategy [INFO] Placing Buy Stop order
# 2022-05-17 00:00:00 strategy [INFO] Placing Sell Market order
# 2022-05-18 00:00:00 strategy [INFO] Placing Buy Stop order
# 2022-05-19 00:00:00 strategy [INFO] Placing Buy Stop order
# 2022-05-20 00:00:00 strategy [INFO] Placing Sell Market order
# 2022-05-24 00:00:00 strategy [INFO] Placing Buy Stop order
# 2022-05-25 00:00:00 strategy [INFO] Placing Buy Stop order
# 2022-05-26 00:00:00 strategy [INFO] Placing Buy Stop order
# 2022-05-27 00:00:00 strategy [INFO] Placing Sell Market order
# 2022-06-13 00:00:00 strategy [INFO] Placing Buy Stop order
# 2022-06-14 00:00:00 strategy [INFO] Placing Buy Stop order
# 2022-06-15 00:00:00 strategy [INFO] Placing Buy Stop order
# 2022-06-16 00:00:00 strategy [INFO] Placing Sell Market order
# 2022-06-17 00:00:00 strategy [INFO] Placing Buy Stop order
# 2022-06-20 00:00:00 strategy [INFO] Placing Buy Stop order
# 2022-06-21 00:00:00 strategy [INFO] Placing Sell Market order
# 2022-06-22 00:00:00 strategy [INFO] Placing Buy Stop order
# 2022-06-23 00:00:00 strategy [INFO] Placing Sell Market order
# 2022-06-24 00:00:00 strategy [INFO] Placing Buy Stop order
# 2022-06-27 00:00:00 strategy [INFO] Placing Sell Market order
# 2022-06-28 00:00:00 strategy [INFO] Placing Buy Stop order
# 2022-06-29 00:00:00 strategy [INFO] Placing Buy Stop order
# 2022-06-30 00:00:00 strategy [INFO] Placing Sell Market order
# 2022-07-01 00:00:00 strategy [INFO] Placing Buy Stop order
# 2022-07-04 00:00:00 strategy [INFO] Placing Sell Market order
# 2022-12-13 23:01:52,105 strategy [INFO] Final portfolio value: $98877.35

# %% [markdown]
# To create a strategy that uses Bollinger Bands and places market and limit orders in PyAlgoTrade, you can use the following steps:
#
# 1. Create a class that extends the `strategy.BacktestingStrategy` class. This class will contain the logic for your trading strategy.
# 2. In the `__init__` method of your `strategy` class, initialize the Bollinger Bands indicator and a `broker.Broker` object. You can use the indicator.BollingerBands class to create the Bollinger Bands indicator, and the `broker.backtesting`.Broker class to create a `broker.Broker` object for backtesting.
# 3. Override the `onBars` method of the `strategy` class. This method is called for each bar in the data set and contains the logic for your trading strategy.
# 4. In the onBars method, use the Bollinger Bands indicator to calculate the upper and lower bands for the current bar. Then, use the `broker.Broker` object to place market and limit orders based on the position of the security relative to the Bollinger Bands. You can use the `broker.placeMarketOrder` and `broker.createLimitOrder` methods to place market and limit orders, respectively.
# 5. To track the position of your investment, you can use the `position.Position` class. In the `onBars` method, create a `position.Position` object for the security and use the update method to update the position with each new trade.
